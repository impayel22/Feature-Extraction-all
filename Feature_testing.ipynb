# %%
from google.colab.patches import cv2_imshow

# %%
# !unzip -u "/content/drive/MyDrive/OCT Project/OCT Code & Dataset/15% reduce splited data/new/train-275.zip" -d "/content"

print('\n\ndone!')
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/OCT Project/OCT Code & Dataset/15% reduce splited data/new/train-275.zip, /content/drive/MyDrive/OCT Project/OCT Code & Dataset/15% reduce splited data/new/train-275.zip.zip or /content/drive/MyDrive/OCT Project/OCT Code & Dataset/15% reduce splited data/new/train-275.zip.ZIP.
#
#
# done!

# %%
# Importing the libraries
import cv2

# Reading the image and converting into B/W
image = cv2.imread('/content/M_ROI 39.png')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Applying the function
fast = cv2.FastFeatureDetector_create()
fast.setNonmaxSuppression(False)

# Drawing the keypoints
kp = fast.detect(gray_image, None)
kp_image = cv2.drawKeypoints(image, kp, None, color=(0, 255, 0))
kp_image
cv2_imshow(kp_image)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=479x485 at 0x7FC28009F520>
# -1

# %% [markdown]
# Convex hull

# %%
import numpy as np
src = cv2.imread("/content/M_ROI 39.png", 1) # read input image

gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY) # convert to grayscale
blur = cv2.blur(gray, (3, 3)) # blur the image
ret, thresh = cv2.threshold(blur, 50, 255, cv2.THRESH_BINARY)

contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# create hull array for convex hull points
hull = []

# calculate points for each contour
for i in range(len(contours)):
    # creating convex hull object for each contour
    hull.append(cv2.convexHull(contours[i], False))

# create an empty black image
drawing = np.zeros((thresh.shape[0], thresh.shape[1], 3), np.uint8)

# draw contours and hull points
for i in range(len(contours)):
    color_contours = (0, 255, 0) # green - color for contours
    color = (255, 0, 0) # blue - color for convex hull
    # draw ith contour
    #cv2.drawContours(drawing, contours, i, color_contours, 1, 8, hierarchy)
    # draw ith convex hull object
    cv2.drawContours(drawing, hull, i, color, 1, 8)

cv2_imshow(drawing)
# Out:
# <PIL.Image.Image image mode=RGB size=479x485 at 0x7FC251C49190>

# %% [markdown]
# Center detection

# %%
# read image through command line
img = cv2.imread("/content/M_ROI 38.png")

# convert the image to grayscale
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# convert the grayscale image to binary image
ret,thresh = cv2.threshold(gray_image,127,255,0)

# find contours in the binary image
contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
for c in contours:
   # calculate moments for each contour
   M = cv2.moments(c)

   # calculate x,y coordinate of center
   cX = int(M["m10"] / M["m00"])
   cY = int(M["m01"] / M["m00"])
   cv2.circle(img, (cX, cY), 1, (255, 0, 255), -1)


   # display the image
   cv2_imshow(img)

# %% [markdown]
# Circle draw

# %%
import cv2
import numpy as np

# read image as grayscale
img = cv2.imread('/content/B_ROI 14.png')

# do canny edge detection
canny = cv2.Canny(img, 100, 200)

# get canny points
# numpy points are (y,x)
points = np.argwhere(canny>0)

# get min enclosing circle
center, radius = cv2.minEnclosingCircle(points)
#print('center:', center, 'radius:', radius)


# draw circle on copy of input
result = img.copy()
x2 = int(center[1])
y2 = int(center[0])
rad2 = int(radius)
cv2.circle(result2, (x2,y2), rad2, (255,255,255), 1)


gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY)
cv2.waitKey(0)
cv2.destroyAllWindows()
height = img.shape[0]
width = img.shape[1]
ave = cv2.mean(thresh)[0]/255
area = ave*height*width

import math
ccarea = math.pi * (radius ** 2)
ratio = ccarea/area


# show results
cv2_imshow(result2)
# Out:
# 77360.2498347727
# 2.0517783215248433
# <PIL.Image.Image image mode=RGB size=555x468 at 0x7FC251D1FB80>

# %% [markdown]
# Circle ratio

# %%
img = cv2.imread('/content/M_ROI 38.png')

# convert the image to grayscale
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# convert the grayscale image to binary image
ret,thresh = cv2.threshold(gray_image,127,255,0)

# find contours in the binary image
contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# Iterate over each contour and calculate its area
total_area = 0
for cnt in contours:
    area = cv2.contourArea(cnt)
    total_area += area
print("Total area of segmented objects:", total_area)
# Out:
# Total area of segmented objects: 9034.0

# %%
# Out:
# 84793.0

# %%
import math
ccarea = math.pi * (197.7880859375 ** 2)
print(ccarea)

ratio = ccarea/area
print(ratio)
# Out:
# 122899.50339849672
# 1.4494062410634925

# %%
#for benign
import cv2
import numpy as np

# read image as grayscale
img2 = cv2.imread('/content/center/benign (12)_mask.png')

# do canny edge detection
canny2 = cv2.Canny(img2, 100, 200)

# get canny points
# numpy points are (y,x)
points2 = np.argwhere(canny2>0)

# get min enclosing circle
center2, radius2 = cv2.minEnclosingCircle(points2)
print('center:', center2, 'radius:', radius2)

# draw circle on copy of input
result2 = img2.copy()
x2 = int(center2[1])
y2 = int(center2[0])
rad2 = int(radius2)
cv2.circle(result2, (x2,y2), rad2, (255,255,255), 1)

# show results
cv2_imshow(result2)
# Out:
# center: (201.5, 381.0) radius: 40.14047622680664
# <PIL.Image.Image image mode=RGB size=678x571 at 0x7F180C58FF40>

# %%
img2 = cv2.imread('/content/center/benign (12)_mask.png')

# convert the image to grayscale
gray_image2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# convert the grayscale image to binary image
ret2,thresh2 = cv2.threshold(gray_image2,127,255,0)

# find contours in the binary image
contours2, hierarchy2 = cv2.findContours(thresh2,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# Iterate over each contour and calculate its area
total_area2 = 0
for cnt2 in contours:
    area2 = cv2.contourArea(cnt2)
    total_area2 += area2
    print("Object area:", area2)
print("Total area of segmented objects:", total_area2)

import math
ccarea2 = math.pi * (82.96092987060547 ** 2)
print("area of circle", ccarea2)

ratio2 = ccarea2/total_area2
print("ratio", ratio2)
# Out:
# Object area: 91886.0
# Total area of segmented objects: 91886.0
# area of circle 21622.061342516976
# ratio 0.23531399062443653

# %% [markdown]
# Eclipse draw

# %%
import cv2
import numpy as np

# read image as grayscale
img = cv2.imread('/content/malignant (2)_mask.png')

# do canny edge detection
canny = cv2.Canny(img, 100, 250)

# transpose canny image to compensate for following numpy points as y,x
canny_t = cv2.transpose(canny)

# get canny points
# numpy points are (y,x)
points = np.argwhere(canny_t>0)

# fit ellipse and get ellipse center, minor and major diameters and angle in degree
ellipse = cv2.fitEllipse(points)
(x,y), (d1,d2), angle = ellipse
print('center: (', x,y, ')', 'diameters: (', d1, d2, ')')

# draw ellipse
result = img.copy()
cv2.ellipse(result, (int(x),int(y)), (int(d1/2),int(d2/2)), angle, 0, 360, (0,0,255), 1)

# show results
cv2_imshow(result)
cv2.waitKey(0)
# Out:
# center: ( 363.28271484375 220.3792266845703 ) diameters: ( 326.110595703125 406.72210693359375 )
# <PIL.Image.Image image mode=RGB size=548x495 at 0x7F17DAEFA4F0>
# -1

# %% [markdown]
# Diameter

# %%
import cv2
import numpy as np

# read image as grayscale
img = cv2.imread('/content/benign (9)_mask.png')

# do canny edge detection
canny = cv2.Canny(img, 100, 200)

# get canny points
# numpy points are (y,x)
points = np.argwhere(canny>0)

# get min enclosing circle
center, radius = cv2.minEnclosingCircle(points)
dia= 2*radius
print('center:', center, 'Diameter:', dia)

# draw circle on copy of input
result = img.copy()
x = int(center[1])
y = int(center[0])
rad = int(radius)
cv2.circle(result, (x,y), rad, (255,255,255), 1)

# show results
cv2_imshow(result)
# Out:
# center: (201.5, 261.5) Diameter: 294.717041015625
# <PIL.Image.Image image mode=RGB size=752x585 at 0x7F11A49FCF40>

# %%
import cv2
import numpy as np

# Load the image
img = cv2.imread('/content/benign (9)_mask.png')

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply a binary threshold to the image to create a mask
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# Find the contours of the object in the mask
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Find the contour with the largest area
max_area = 0
max_contour = None
for contour in contours:
    area = cv2.contourArea(contour)
    if area > max_area:
        max_area = area
        max_contour = contour

# Find the minimum enclosing circle of the contour
(center, radius) = cv2.minEnclosingCircle(max_contour)

# Draw the minimum enclosing circle on the original image
cv2.circle(img, (int(center[0]), int(center[1])), int(radius), (0, 255, 0), 2)

# Find the two points on the circle's edge that are farthest apart
farthest_points = None
max_distance = 0
for i in range(len(max_contour)):
    for j in range(i+1, len(max_contour)):
        distance = np.linalg.norm(max_contour[i][0] - max_contour[j][0])
        if distance > max_distance:
            max_distance = distance
            farthest_points = (max_contour[i][0], max_contour[j][0])

# Calculate the shortest diameter as the distance between the two farthest points
shortest_diameter = max_distance

# Draw the shortest diameter on the original image
cv2.line(img, (int(farthest_points[0][0]), int(farthest_points[0][1])), (int(farthest_points[1][0]), int(farthest_points[1][1])), (255, 0, 0), 2)

# Show the result
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=752x585 at 0x7F11B15425B0>

# %%
import math

# Define the coordinates of the two points
x1, y1 = int(farthest_points[0][0]), int(farthest_points[0][1])
x2, y2 = int(farthest_points[1][0]), int(farthest_points[1][1])

# Calculate the length of the line using the Pythagorean theorem
length = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

print("The length of the line is:", length)
# Out:
# The length of the line is: 293.7430850249925

# %%
import cv2
import numpy as np
from scipy.spatial import distance_matrix

# Read the image and convert it to grayscale
image = cv2.imread('/content/benign (9)_mask.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Threshold the grayscale image to obtain a binary image
_, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Find the contours in the binary image
contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Find the contour with the largest area
largest_contour = max(contours, key=cv2.contourArea)

# Find the convex hull of the largest contour
hull = cv2.convexHull(largest_contour)

# Compute the pairwise distances between points on the convex hull
distances = distance_matrix(hull[:,0], hull[:,0])

# Find the pair of points on the convex hull with the largest distance
max_dist = np.max(distances)
for i in range(len(hull)):
    for j in range(i+1, len(hull)):
        dist = distances[i,j]
        if dist == max_dist:
            p1, p2 = tuple(hull[i][0]), tuple(hull[j][0])
            break

# Draw the convex hull and the diameter on the image
cv2.drawContours(image, [hull], -1, (0, 255, 0), 2)
cv2.line(image, p1, p2, (0, 0, 255), 2)

# Display the image
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Print the length of the diameter
print("The length of the smallest diameter is:", max_dist)
# Out:
# <PIL.Image.Image image mode=RGB size=752x585 at 0x7F11A4A18EB0>
# The length of the smallest diameter is: 293.7430850249925

# %%
import cv2
import numpy as np

# Read the image and convert it to grayscale
image = cv2.imread('/content/malignant (25)_mask.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Threshold the grayscale image to obtain a binary image
_, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Find the contours in the binary image
contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Find the contour with the largest area
largest_contour = max(contours, key=cv2.contourArea)

# Find the convex hull of the largest contour
hull = cv2.convexHull(largest_contour)

# Find the farthest points on the convex hull
distances = cv2.distanceTransform(binary, cv2.DIST_L2, cv2.DIST_MASK_PRECISE)
farthest_points = np.unravel_index(distances.argmax(), distances.shape)

# Compute the diameter of the object
diameter = distances[farthest_points]

# Draw the convex hull and the diameter on the image
cv2.circle(image, (farthest_points[1], farthest_points[0]), int(diameter), (0, 0, 255), 2)

# Display the image
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Print the length of the diameter
print("The length of the smallest diameter is:", diameter)
# Out:
# <PIL.Image.Image image mode=RGB size=563x470 at 0x7F11A49FC3D0>
# The length of the smallest diameter is: 118.40608

# %% [markdown]
# Segment

# %%
import cv2
import numpy as np
from scipy.spatial import distance_matrix

# Read the image and convert it to grayscale
src = cv2.imread('/content/downloadbnmn.png')
gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY) # convert to grayscale
blur = cv2.blur(gray, (3, 3)) # blur the image
ret, thresh = cv2.threshold(blur, 50, 255, cv2.THRESH_BINARY)

contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# create hull array for convex hull points
hull = []

# calculate points for each contour
for i in range(len(contours)):
    # creating convex hull object for each contour
    hull.append(cv2.convexHull(contours[i], False))


# draw contours and hull points
for i in range(len(contours)):
    color_contours = (0, 255, 0) # green - color for contours
    color = (255, 0, 0) # blue - color for convex hull
    # draw ith contour
    cv2.drawContours(thresh, contours, i, color_contours, 1, 8, hierarchy)


cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=121x115 at 0x7FEA2E6B33D0>

# %%
import cv2
import numpy as np

# Load input image
img = cv2.imread("/content/thresh.png")

# Convert image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply threshold to obtain binary image with black background and white foreground
_, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV)

# Perform morphological closing operation with a square kernel of size 5x5
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
closed = cv2.morphologyEx(gray, cv2.MORPH_CLOSE, kernel)

# Perform morphological opening operation with a square kernel of size 5x5
opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel)

# Invert the image to obtain black foreground and white background
filled = 255 - opened

# Create a white mask with the same size as the input image
mask = np.ones_like(img, np.uint8) * 255

# Copy the filled image to the mask using the filled image as a mask
mask[filled == 255] = img[filled == 255]


cv2.imwrite("/content/opclo.jpg", mask)

# Show the inverted image
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=RGB size=121x115 at 0x7FEA2E6120A0>

# %%
import cv2
import numpy as np

# Let's load a simple image with 3 black squares
image = cv2.imread('/content/opclo.jpg')
cv2.waitKey(0)

# Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Find Canny edges
edged = cv2.Canny(gray, 30, 200)
cv2.waitKey(0)

# Finding Contours
# Use a copy of the image e.g. edged.copy()
# since findContours alters the image
contours, hierarchy = cv2.findContours(edged,
	cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)


print("Number of Contours found = " + str(len(contours)))

# Draw all contours
# -1 signifies drawing all contours
cv2.drawContours(image, contours, -1, (0, 255, 0), 1)

cv2.imwrite("/content/contor.jpg", image)
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Number of Contours found = 9
# <PIL.Image.Image image mode=RGB size=121x115 at 0x7FEA2E6126A0>

# %%
import cv2

# Load image
img = cv2.imread("/content/contor.jpg")

# Apply median filter
img_filtered = cv2.medianBlur(img, 5)

cv2.imwrite("/content/filter.jpg", image)

# Display result
cv2_imshow(img_filtered)
# Out:
# <PIL.Image.Image image mode=RGB size=121x115 at 0x7FEA6284BEB0>

# %%
import cv2
import numpy as np

# Load input image
img = cv2.imread("/content/filter.jpg")

# Convert image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply binary thresholding to obtain a binary image
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# Perform morphological closing operation with a rectangular kernel to fill any gaps or holes in the shape
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
closed = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Perform morphological opening operation with a smaller rectangular kernel to remove small white spaces
kernel2 = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel2)

# Invert the image
inverted = cv2.bitwise_not(opened)

# Save the output image
cv2.imwrite('/content/mask2.jpg', inverted)


# Show the inverted image
cv2_imshow(inverted)
# Out:
# <PIL.Image.Image image mode=L size=121x115 at 0x7FEA2F230C70>

# %%
import cv2

# Load the image
img = cv2.imread("/content/mask2.jpg")

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Threshold the image to obtain a binary image
ret, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# Find the contours in the binary image
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# Find the largest contour, which should correspond to the large white shape
max_area = 0
largest_contour = None
for contour in contours:
    area = cv2.contourArea(contour)
    if area > max_area:
        max_area = area
        largest_contour = contour

# Create a black mask image of the same size as the original image
mask = np.zeros_like(img)

# Draw the largest contour in white on the black mask image
cv2.drawContours(mask, [largest_contour], 0, (255, 255, 255), -1)

# Use the bitwise AND operator to apply the mask to the original image
result = cv2.bitwise_not(img, mask)

# Display the result
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=121x115 at 0x7FEA6284B6A0>

# %%
import cv2


# Grayscale
gray = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)

# Find Canny edges
edged = cv2.Canny(gray, 30, 200)
cv2.waitKey(0)

# Finding Contours
# Use a copy of the image e.g. edged.copy()
# since findContours alters the image
contours, hierarchy = cv2.findContours(edged,
	cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
# Find the largest contour, which should correspond to the large white shape
max_area = 0
largest_contour = None
for contour in contours:
    area = cv2.contourArea(contour)
    if area > max_area:
        max_area = area
        largest_contour = contour

# Create a black mask image of the same size as the original image
mask = np.zeros_like(img)

# Draw the largest contour in white on the black mask image
cv2.drawContours(mask, [largest_contour], 0, (255, 0, 255), 2)

# Use the bitwise AND operator to apply the mask to the original image
result2 = cv2.bitwise_and(img, mask)

# Display the result
cv2_imshow(result2)
# Out:
# <PIL.Image.Image image mode=RGB size=121x115 at 0x7FEA6284BCA0>

# %%
#artifacts remove
import cv2 as cv
import numpy as np
imgeb = cv.imread('/content/benign (3).png',0)
kernel = np.ones((4,4),np.uint8)
erosioni = cv.erode(imgeb,kernel,iterations = 1)
cv2_imshow(erosioni)
# Out:
# <PIL.Image.Image image mode=L size=558x471 at 0x7FB09C27EC70>

# %%
#mask region smaller using erosion
import cv2 as cv
import numpy as np
img = cv.imread('/content/malignant (1)_mask.png',0)
kernel = np.ones((90,90),np.uint8)
erosion = cv.erode(img,kernel,iterations = 1)
imgmr=img-erosion
cv2_imshow(imgmr)
# Out:
# <PIL.Image.Image image mode=L size=449x598 at 0x7FB09C27E430>

# %%
#area of the image
img=cv.imread("/content/malignant (3).png",0)
img2=cv.imread("/content/malignant (3)_mask.png",0)
resultb2 = cv.bitwise_and(img, img2)
#cv.imwrite("/content/roip_mal1_erom1.jpg", resultb9)
cv2_imshow(resultb2)
# Out:
# <PIL.Image.Image image mode=L size=425x475 at 0x7FB09C12EA90>

# %%
#area of the image


resultb9 = cv.bitwise_and(erosioni, erosion)
#cv.imwrite("/content/roip_mal1_erom1.jpg", resultb9)
cv2_imshow(resultb9)
# Out:
# <PIL.Image.Image image mode=L size=752x585 at 0x7FB09C1F5670>

# %%
import cv2 as cv
import numpy as np
#img11 = cv.imread('/content/roip_mal1.jpg',0)
#img22=cv.imread("/content/roip_mal1_dila.jpg",0)

img33= resultb2-resultb9
#cv.imwrite("/content/echo_mal1_sidearea.jpg", img33)
cv2_imshow(img33)
# Out:
# <PIL.Image.Image image mode=L size=752x585 at 0x7FB09C1F59D0>

# %%
kernel = np.ones((4,4),np.uint8)
erosion33 = cv.erode(img33,kernel,iterations = 1)
#cv.imwrite("/content/aml1_sidearea.jpg", erosion33)
cv2_imshow(erosion33)
# Out:
# <PIL.Image.Image image mode=L size=752x585 at 0x7FB09C1F53A0>
